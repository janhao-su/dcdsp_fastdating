# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

def print_full(x):
    pd.set_option('display.max_rows', len(x))
    f = open('output.txt', 'w')
    print(x)
    print >> f, x
    pd.reset_option('display.max_rows')
    f.close()
    
    pass
data_df = pd.read_csv("speed_dating_train.csv", encoding="ISO-8859-1")


total = data_df.isnull().sum().sort_values(ascending=False)
percent = (data_df.isnull().sum()/data_df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
dense_data_index = missing_data[missing_data.Percent <0.1].index
dense_data = data_df[(missing_data[missing_data.Percent <0.1].index)].drop("recordid",1)
del_item = dense_data[dense_data.isnull().any(1)].index
dense_data_clean = dense_data.drop(del_item)
train_df = dense_data_clean.sample(4000)
train_df_x = train_df.drop("match",1)
train_df_y = train_df.match

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', degree=1)
#model = clf.fit(train_df_x, train_df_y)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-102-2a0e33eb5e1e> in <module>()
#       1 from sklearn.svm import SVC
#       2 clf = SVC(kernel='poly', degree=1)
# ----> 3 model = clf.fit(train_df_x, train_df_y)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     149         self._sparse = sparse and not callable(self.kernel)
#     150
# --> 151         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     152         y = self._validate_targets(y)
#     153
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# ...

# %%
import matplotlib.pyplot as plt
#fig, axes = plt.subplots(1,1)
data_df.wave.hist().plot()
plt.show()

# %%
a= dense_data.columns
#k = len(dense_data.columns) #number of variables for heatmap
#cols = corrmat.nlargest(k, 'match')['match'].index
num_set = dense_data_clean.drop(['career','from','field'],1);
col = num_set.columns
col = col[0:1]
#col
x = num_set[col];
x
import seaborn as sns
sns.heatmap(x,annot=True)
plt.show()
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-123-8e1d049b6802> in <module>()
#      10 import seaborn as sns
#      11 sns.heatmap(x,annot=True)
# ---> 12 plt.show()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     250     """
#     251     global _show
# --> 252     return _show(*args, **kw)
#     253
#     254
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     162             publish_display_data(data=obj, metadata=metadata)
#     163         else:
# --> 164             format_dict, md_dict = format(obj, include=include, exclude=exclude)
# ...
